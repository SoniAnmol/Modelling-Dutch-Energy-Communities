# %%
# This notebook reads the results and return average demand for each agent

# %%
from results.results import *

# %%
# Read the results

# %%
results = pd.read_csv('../results/simulation_results.csv')

# %%
results
# Out:
#     energy costs                                   avg agent demand  \
# 0            NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 1            NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 2            NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 3            NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 4            NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 5            NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 6            NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 7            NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 8            NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 9            NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 10           NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 11           NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 12           NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 13           NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 14           NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 15           NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 16           NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 17           NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 18           NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 19           NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 20           NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 21           NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 22           NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 23           NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 24           NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 25           NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 26           NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 27           NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 28           NaN  {"<class 'model.agents.Residential'>": [0.1880...
# 29           NaN  {"<class 'model.agents.Residential'>": [0.1880...
#
#                                    total agent demand  \
# 0   {"<class 'model.agents.Residential'>": [1.8800...
# 1   {"<class 'model.agents.Residential'>": [1.8800...
# 2   {"<class 'model.agents.Residential'>": [1.8800...
# 3   {"<class 'model.agents.Residential'>": [1.8800...
# 4   {"<class 'model.agents.Residential'>": [1.8800...
# 5   {"<class 'model.agents.Residential'>": [1.8800...
# 6   {"<class 'model.agents.Residential'>": [1.8800...
# 7   {"<class 'model.agents.Residential'>": [1.8800...
# 8   {"<class 'model.agents.Residential'>": [1.8800...
# 9   {"<class 'model.agents.Residential'>": [1.8800...
# 10  {"<class 'model.agents.Residential'>": [1.8800...
# 11  {"<class 'model.agents.Residential'>": [1.8800...
# 12  {"<class 'model.agents.Residential'>": [1.8800...
# 13  {"<class 'model.agents.Residential'>": [1.8800...
# 14  {"<class 'model.agents.Residential'>": [1.8800...
# 15  {"<class 'model.agents.Residential'>": [1.8800...
# 16  {"<class 'model.agents.Residential'>": [1.8800...
# 17  {"<class 'model.agents.Residential'>": [1.8800...
# 18  {"<class 'model.agents.Residential'>": [1.8800...
# 19  {"<class 'model.agents.Residential'>": [1.8800...
# 20  {"<class 'model.agents.Residential'>": [1.8800...
# 21  {"<class 'model.agents.Residential'>": [1.8800...
# 22  {"<class 'model.agents.Residential'>": [1.8800...
# 23  {"<class 'model.agents.Residential'>": [1.8800...
# 24  {"<class 'model.agents.Residential'>": [1.8800...
# 25  {"<class 'model.agents.Residential'>": [1.8800...
# 26  {"<class 'model.agents.Residential'>": [1.8800...
# 27  {"<class 'model.agents.Residential'>": [1.8800...
# 28  {"<class 'model.agents.Residential'>": [1.8800...
# 29  {"<class 'model.agents.Residential'>": [1.8800...
#
#                                      total generation  \
# 0   {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 1   {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 2   {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 3   {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 4   {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 5   {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 6   {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 7   {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 8   {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 9   {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 10  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 11  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 12  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 13  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 14  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 15  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 16  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 17  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 18  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 19  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 20  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 21  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 22  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 23  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 24  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 25  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 26  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 27  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 28  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 29  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
#
#                                        avg generation
# 0   {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 1   {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 2   {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 3   {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 4   {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 5   {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 6   {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 7   {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 8   {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 9   {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 10  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 11  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 12  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 13  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 14  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 15  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 16  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 17  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 18  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 19  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 20  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 21  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 22  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 23  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 24  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 25  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 26  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 27  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 28  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....
# 29  {"<class 'model.agents.Solar'>": [0.0, 0.0, 0....

# %%
agent_list = [NonResidential]
avg_demand = extract_results(results, column='avg agent demand', agent_list=agent_list)
plot_results(avg_demand, plt_title='Average demand of a single non-residential agent', kind='line', stacked=False)

# %%
agent_list = [Residential]
avg_demand = extract_results(results, column='avg agent demand', agent_list=agent_list)
plot_results(avg_demand, plt_title='Average demand of a single household', kind='line', stacked=False)

# %%
agent_list = [Residential, NonResidential]
total_demand = extract_results(results, column='total agent demand', agent_list=agent_list)
plot_results(total_demand, plt_title='Total average demand of all agents', kind='area', stacked=True)

# %%
generators = [Solar]
total_demand = avg_demand = extract_results(results, column='total generation', agent_list=generators)
plot_results(total_demand, plt_title='Total generation', kind='area', stacked=False)

# %%
fig, ax = plt.subplots(figsize=(10, 5))
total_demand.plot(ax=ax)
total_demand['Solar'].mean(axis=0).plot(ax=ax, color='red', linewidth=2)
plt.xlabel('Hours')
plt.ylabel('kWh')
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [40], in <module>
#       1 fig, ax = plt.subplots(figsize=(10, 5))
#       2 total_demand.plot(ax=ax)
# ----> 3 total_demand['Solar'].mean(axis=0).plot(ax=ax, color='red', linewidth=2)
#       4 plt.xlabel('Hours')
#       5 plt.ylabel('kWh')
#
# AttributeError: 'numpy.float64' object has no attribute 'plot'

# %%
total_demand['Solar'].quantile(0.7)

# %%
total_demand[total_demand['Solar'] > total_demand['Solar'].quantile(0.70)].index

# %%
demand

# %%
generators = [Solar]
total_demand = avg_demand = extract_results(results, column='avg generation', agent_list=generators)
plot_results(total_demand, plt_title='Average generation', kind='line', stacked=False)

# %% [markdown]
# ___

# %%
solar_plants = [{'capacity': 2000, 'efficiency': 0.20, 'price': 0.15, 'owner': 'KoningDrinks'},
                {'capacity': 2000, 'efficiency': 0.20, 'price': 0.15, 'owner': 'KoningDrinks'}]
