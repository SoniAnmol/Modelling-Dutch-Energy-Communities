# %%
# This notebook reads the results and return average demand for each agent

# %%
from model.agents import *
from results.results import *

# %%
# Read the results

# %%
results = pd.read_csv('../results/simulation_results.csv')

# %%
results
# Out:
#                                           energy costs  \
# 0    [11202.92136419 11371.16182548 11370.33311801 ...
# 1    [13220.29636951 13162.38341865 13077.08728039 ...
# 2    [24957.72330998 24647.16338568 25011.61727666 ...
# 3    [12313.15161647 12646.04415204 12308.80721068 ...
# 4    [24014.89709316 23578.04980998 24241.48554528 ...
# ..                                                 ...
# 360  [14302.17996155 14463.44645026 14401.3525542  ...
# 361  [10487.81255345 10618.71496138 10541.83411804 ...
# 362  [10990.54805775 11140.30953323 11301.30338966 ...
# 363  [19452.25448868 19495.46673516 20114.29461273 ...
# 364  [9086.11472577 9145.95322998 9016.40751157 908...
#
#                                       avg agent demand  \
# 0    {"<class 'model.agents.Residential'>": [48.950...
# 1    {"<class 'model.agents.Residential'>": [50.415...
# 2    {"<class 'model.agents.Residential'>": [49.732...
# 3    {"<class 'model.agents.Residential'>": [50.447...
# 4    {"<class 'model.agents.Residential'>": [50.107...
# ..                                                 ...
# 360  {"<class 'model.agents.Residential'>": [50.278...
# 361  {"<class 'model.agents.Residential'>": [49.771...
# 362  {"<class 'model.agents.Residential'>": [49.184...
# 363  {"<class 'model.agents.Residential'>": [50.036...
# 364  {"<class 'model.agents.Residential'>": [48.957...
#
#                                     total agent demand  \
# 0    {"<class 'model.agents.Residential'>": [14685....
# 1    {"<class 'model.agents.Residential'>": [15124....
# 2    {"<class 'model.agents.Residential'>": [14919....
# 3    {"<class 'model.agents.Residential'>": [15134....
# 4    {"<class 'model.agents.Residential'>": [15032....
# ..                                                 ...
# 360  {"<class 'model.agents.Residential'>": [15083....
# 361  {"<class 'model.agents.Residential'>": [14931....
# 362  {"<class 'model.agents.Residential'>": [14755....
# 363  {"<class 'model.agents.Residential'>": [15010....
# 364  {"<class 'model.agents.Residential'>": [14687....
#
#                                       total generation  \
# 0    {"<class 'model.agents.Solar'>": [2.6985243626...
# 1    {"<class 'model.agents.Solar'>": [2.6985243626...
# 2    {"<class 'model.agents.Solar'>": [2.6985243626...
# 3    {"<class 'model.agents.Solar'>": [2.6985243626...
# 4    {"<class 'model.agents.Solar'>": [2.6985243626...
# ..                                                 ...
# 360  {"<class 'model.agents.Solar'>": [2.6985243626...
# 361  {"<class 'model.agents.Solar'>": [2.6985243626...
# 362  {"<class 'model.agents.Solar'>": [2.6985243626...
# 363  {"<class 'model.agents.Solar'>": [2.6985243626...
# 364  {"<class 'model.agents.Solar'>": [2.6985243626...
#
#                                         avg generation
# 0    {"<class 'model.agents.Solar'>": [2.6985243626...
# 1    {"<class 'model.agents.Solar'>": [2.6985243626...
# 2    {"<class 'model.agents.Solar'>": [2.6985243626...
# 3    {"<class 'model.agents.Solar'>": [2.6985243626...
# 4    {"<class 'model.agents.Solar'>": [2.6985243626...
# ..                                                 ...
# 360  {"<class 'model.agents.Solar'>": [2.6985243626...
# 361  {"<class 'model.agents.Solar'>": [2.6985243626...
# 362  {"<class 'model.agents.Solar'>": [2.6985243626...
# 363  {"<class 'model.agents.Solar'>": [2.6985243626...
# 364  {"<class 'model.agents.Solar'>": [2.6985243626...
#
# [365 rows x 5 columns]

# %%
agent_list = [Residential, Commercial, Utility, School, EVChargingStation]
avg_demand = extract_results(results, column='avg agent demand', agent_list=agent_list)
plot_results(avg_demand, plt_title='Average demand', kind= 'line', stacked=False)

# %%
total_demand = avg_demand = extract_results(results, column='total agent demand', agent_list=agent_list)
plot_results(total_demand, plt_title='Total demand', kind= 'area', stacked=True)

# %%
generators = [Solar, Wind]
total_demand = avg_demand = extract_results(results, column='total generation', agent_list=generators)
plot_results(total_demand, plt_title='Total generation', kind= 'area', stacked=False)

# %%
generators = [Solar, Wind]
total_demand = avg_demand = extract_results(results, column='avg generation', agent_list=generators)
plot_results(total_demand, plt_title='Average generation', kind= 'line', stacked=False)
