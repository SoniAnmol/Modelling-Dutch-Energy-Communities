# %% [markdown]
# # Data Preparation
#
# This notebook is used to prepare the data for the model.

# %% [markdown]
# 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# 2. Read cleaned data

# %%
df = pd.read_csv('processed/cleaned_data.csv')

# %%
df.head(5)
# Out:
#                  Local  Office 1  Office 2  Office 3  Office 4     School  \
# 0  2021-01-01 00:30:00       9.4       4.8       1.8      18.5  12.336667
# 1  2021-01-01 00:45:00       9.4       5.1       1.8      17.0  11.323333
# 2  2021-01-01 01:00:00       9.4       4.8       1.7      21.0  11.915000
# 3  2021-01-01 01:15:00       9.6       4.6       1.8      17.5  11.575000
# 4  2021-01-01 01:30:00       8.7       4.6       1.8      20.0  12.170000
#
#        date_x  Irradiance [W/m^2]  T_ambient [Degrees Celsius]  \
# 0  2021-01-01                 0.0                       3066.0
# 1  2021-01-01                 0.0                       3066.0
# 2  2021-01-01                 0.0                       3066.0
# 3  2021-01-01                 0.0                       3066.0
# 4  2021-01-01                 0.0                       2949.0
#
#    T_ground [Degrees Celsius]  Wind [m/s]  Cloud [okta]  Pressure [Pa]  \
# ...

# %% [markdown]
# 3. Prepare data for schools

# %%
# Comparing area of source school and target school
# Source school is the school from which data is collected.

floor_area_of_source = 27,000
floor_area_of_school = 0

# %% [markdown]
# 4. Prepare data for offices

# %% [markdown]
# 5. Prepare data for residential buildings

# %% [markdown]
# 6. Prepare data for EV-bus charging stations

# %% [markdown]
# 7. Combine all data

# %% [markdown]
# 8. Store data in a csv file

# %%
import fiona

# %%
shape = fiona.open("raw/GIS/GIS/Warmtenet.shp")

# %%
shape.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [548], in <module>
# ----> 1 shape.plot()
#
# AttributeError: 'Collection' object has no attribute 'plot'

# %%
print (shape.schema)
# Out:
# {'properties': OrderedDict([('id', 'int:10')]), 'geometry': 'LineString'}

# %%
first = shape.next()
print (first)
# Out:
# {'type': 'Feature', 'id': '0', 'properties': OrderedDict([('id', 1)]), 'geometry': {'type': 'LineString', 'coordinates': [(4.811721330318608, 51.607368578272826), (4.807456049987522, 51.60674246098261), (4.801639758626949, 51.60717592771857), (4.791609887302938, 51.60797863296808), (4.790782681420546, 51.60915055714553), (4.781424914875978, 51.60995322748175), (4.778969147412627, 51.610595353532325), (4.776565080316923, 51.61131773448224), (4.774419515059467, 51.61154247287768), (4.771860346860814, 51.61152642017203), (4.766405958073788, 51.612216681388055), (4.76051211616174, 51.61293903653689), (4.757539345021893, 51.61332428791592), (4.755471330315911, 51.613581120352045), (4.754049570205549, 51.61332428791592), (4.754178821124673, 51.61228089120013), (4.754178821124673, 51.61143010381905), (4.753946169470251, 51.610531141336), (4.753093113404032, 51.60934319932056), (4.7522659075216405, 51.608123118405736), (4.751723053661321, 51.60727225309789), (4.751257750352474, 51.6068869503
# ...

# %%
import geopandas as gpd

# %%
# heat_network = gpd.read_file("raw/GIS/GIS/Warmtenet.shp")
buildings = gpd.read_file("raw/GIS/GIS/Initiatieven.shp")
neighborhoods = gpd.read_file("raw/GIS/GIS/Data/Buurten/Buurten.shp")
neighborhood_energy_code = gpd.read_file("raw/GIS/GIS/Data/Download-BuurtEnergieInfo-SHP/BuurtEnergieCodes_v.shp")

# %%
buildings.to_crs(epsg=4326, inplace=True)

# %%
buildings.crs
# Out:
# <Derived Projected CRS: EPSG:28992>
# Name: Amersfoort / RD New
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: Netherlands - onshore, including Waddenzee, Dutch Wadden Islands and 12-mile offshore coastal zone.
# - bounds: (3.2, 50.75, 7.22, 53.7)
# Coordinate Operation:
# - name: RD New
# - method: Oblique Stereographic
# Datum: Amersfoort
# - Ellipsoid: Bessel 1841
# - Prime Meridian: Greenwich

# %%
buildings = buildings[buildings['Initiatief'] != 'Bavelse Berg']

# %%
fig, ax = plt.subplots(1, figsize=(10,10))
# heat_network.plot(ax=ax, color='red')
# neighborhoods.plot(ax=ax, color='green')
# neighborhood_energy_code.plot(ax=ax, color='green')
buildings.plot(ax=ax, color='blue')
# Out:
# <AxesSubplot:>

# %%
buildings_json = buildings['geometry'].to_json()

# %%
import plotly.express as px

# %%
token = 'pk.eyJ1IjoiYW5tb2xzb25pMTIzIiwiYSI6ImNrbXoxeTMwdjA2aTcycHF1M2lmb29senIifQ.nXyfPKmF31PKfFZsA7Fb1g'

# %%
fig = px.choropleth_mapbox(buildings, locations='id',
                    color='Initiatief',
                    geojson=buildings_json,
                    hover_name='Initiatief',
                    center={"lat": 51.59926, "lon": 4.80896},
                    mapbox_style="carto-positron",
                    opacity=0.5,
                    zoom=13,)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <div>                            <div id="10d93be0-996f-4b19-b874-dffa9cc25f6d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("10d93be0-996f-4b19-b874-dffa9cc25f6d")) {                    Plotly.newPlot(                        "10d93be0-996f-4b19-b874-dffa9cc25f6d",                        [{"colorscale":[[0.0,"#636efa"],[1.0,"#636efa"]],"geojson":"{\"type\": \"FeatureCollection\", \"features\": [{\"id\": \"0\", \"type\": \"Feature\", \"properties\": {}, \"geometry\": null, \"bbox\": null}, {\"id\": \"1\", \"type\": \"Feature\", \"properties\": {}, \"geometry\": {\"type\": \"Polygon\", \"coordinates\": [[[114936.9784791641, 401310.7948340654], [114986.8416117061, 401300.86074397375], [114983.22833126232, 401280.6994094986], [114933.35911692106, 4012
# ...

# %%
buildings
# Out:
#     id                             Initiatief Opwek (MW) Verbr (MW)  \
# 0    1                                  Curio       None       None
# 1    2         Bedrijventerrein Druivenstraat       None       None
# 2    3                                 Sligro       None       None
# 3    4                         Konings Drinks       None       None
# 4    5  Wonen Breburg - Tijdelijke woningbouw       None       None
# 5    6                              Busremise       None       None
# 6    7                           Gemeentewerf       None       None
# 8    9                       Digit Park Breda       None       None
# 9   11                                  Curio       None       None
# 10  12                                  Curio       None       None
# 11  13                                  Curio       None       None
# 12  14                                  Curio       None       None
# 13  16                                  Curio       None       None
# ...
